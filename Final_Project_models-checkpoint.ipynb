# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import make_classification
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import cpi
cpi.update()
from datetime import date
from sqlalchemy import create_engine
import tensorflow as tf

# %%
# Read in data
tornado_data = pd.read_csv('Tornadoes_SPC_1950to2015.csv')
tornado_data.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'stf', 'stn', 'mag',
#        'inj', 'fat', 'loss', 'closs', 'slat', 'slon', 'elat', 'elon', 'len',
#        'wid', 'fc'],
#       dtype='object')

# %%
# Clean up file
tornado_data.rename(columns = {'yr':'Year', 'mo':'Month','dy':'Day','date':'Date','time':'Time','tz':'Time_Zone',
                               'st':'State','stf':'State_FIPS','stn':'State_No','mag':'Magnitude','inj':'Injuries',
                               'fat':'Fatalities','loss':'Property_Loss','closs':'Crop_Loss','slat':'Starting_Lat',
                               'slon':'Starting_Lon','elat':'Ending_Lat','elon':'Ending_Lon','len':'Length',
                               'wid':'Width'}, inplace = True)
tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 60109  607506  2015     12   28  12/28/2015   3:20:00          3    LA
# 60110  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 60111  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 60112  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 60113  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Fatalities  Property_Loss  Crop_Loss  \
# 0              29         1  ...           0           6.00        0.0
# 1              17         2  ...           0           5.00        0.0
# 2              39         1  ...           0           4.00        0.0
# 3               5         1  ...           1           3.00        0.0
# 4              29         2  ...           0           5.00        0.0
# ...           ...       ...  ...         ...            ...        ...
# 60109          22         0  ...           0           0.00        0.0
# 60110           5         0  ...           0           0.05        0.0
# 60111          28         0  ...           0           0.10        0.0
# 60112          12         0  ...           0           0.01        0.0
# 60113          37         0  ...           0           0.05        0.0
#
#        Starting_Lat  Starting_Lon  Ending_Lat  Ending_Lon  Length  Width  fc
# 0             38.77        -90.22       38.83      -90.03    9.50    150   0
# 1             39.10        -89.30       39.12      -89.23    3.60    130   0
# 2             40.88        -84.58        0.00        0.00    0.10     10   0
# 3             34.40        -94.37        0.00        0.00    0.60     17   0
# 4             37.60        -90.68       37.63      -90.65    2.30    300   0
# ...             ...           ...         ...         ...     ...    ...  ..
# 60109         30.08        -90.54       30.08      -90.53    0.60    150   0
# 60110         34.70        -90.92       34.78      -90.90    5.75     40   0
# 60111         31.54        -89.53       31.61      -89.49    5.59    100   0
# 60112         30.76        -87.24       30.77      -87.23    0.78     75   0
# 60113         34.88        -80.53       34.89      -80.52    0.90     75   0
#
# [60114 rows x 22 columns]

# %%
# Remove zeroes from Property Loss column
# tornado_data = tornado_data[tornado_data['Property_Loss'] > 0]
# tornado_data

# %%
# Translate Property Loss to $ amounts - use midpoint in each range, translate to fraction of million
# 1 = .000025
# 2 = .000275
# 3 = .00275
# 4 = .0275
# 5 = .275
# 6 = 2.75
# 7 = 27.5
# 8 = 275
# 9 = 2750

tornado_data['Property_Loss'] = tornado_data['Property_Loss'].replace([1, 2, 3, 4, 5, 6, 7, 8, 9], 
                                    [.000025, .000275, .00275, .0275, .275, 2.75, 27.5, 275, 2750])
tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 60109  607506  2015     12   28  12/28/2015   3:20:00          3    LA
# 60110  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 60111  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 60112  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 60113  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Fatalities  Property_Loss  Crop_Loss  \
# 0              29         1  ...           0        2.75000        0.0
# 1              17         2  ...           0        0.27500        0.0
# 2              39         1  ...           0        0.02750        0.0
# 3               5         1  ...           1        0.00275        0.0
# 4              29         2  ...           0        0.27500        0.0
# ...           ...       ...  ...         ...            ...        ...
# 60109          22         0  ...           0        0.00000        0.0
# 60110           5         0  ...           0        0.05000        0.0
# 60111          28         0  ...           0        0.10000        0.0
# 60112          12         0  ...           0        0.01000        0.0
# 60113          37         0  ...           0        0.05000        0.0
#
#        Starting_Lat  Starting_Lon  Ending_Lat  Ending_Lon  Length  Width  fc
# 0             38.77        -90.22       38.83      -90.03    9.50    150   0
# 1             39.10        -89.30       39.12      -89.23    3.60    130   0
# 2             40.88        -84.58        0.00        0.00    0.10     10   0
# 3             34.40        -94.37        0.00        0.00    0.60     17   0
# 4             37.60        -90.68       37.63      -90.65    2.30    300   0
# ...             ...           ...         ...         ...     ...    ...  ..
# 60109         30.08        -90.54       30.08      -90.53    0.60    150   0
# 60110         34.70        -90.92       34.78      -90.90    5.75     40   0
# 60111         31.54        -89.53       31.61      -89.49    5.59    100   0
# 60112         30.76        -87.24       30.77      -87.23    0.78     75   0
# 60113         34.88        -80.53       34.89      -80.52    0.90     75   0
#
# [60114 rows x 22 columns]

# %%
# Adjust $ amount for inflation
tornado_data["Adj_Property_Loss"] = tornado_data.apply(lambda x: cpi.inflate(x["Property_Loss"], x["Year"]), axis=1)

tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 60109  607506  2015     12   28  12/28/2015   3:20:00          3    LA
# 60110  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 60111  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 60112  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 60113  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Property_Loss  Crop_Loss  Starting_Lat  \
# 0              29         1  ...        2.75000        0.0         38.77
# 1              17         2  ...        0.27500        0.0         39.10
# 2              39         1  ...        0.02750        0.0         40.88
# 3               5         1  ...        0.00275        0.0         34.40
# 4              29         2  ...        0.27500        0.0         37.60
# ...           ...       ...  ...            ...        ...           ...
# 60109          22         0  ...        0.00000        0.0         30.08
# 60110           5         0  ...        0.05000        0.0         34.70
# 60111          28         0  ...        0.10000        0.0         31.54
# 60112          12         0  ...        0.01000        0.0         30.76
# 60113          37         0  ...        0.05000        0.0         34.88
#
#        Starting_Lon  Ending_Lat  Ending_Lon  Length  Width  fc  \
# 0            -90.22       38.83      -90.03    9.50    150   0
# 1            -89.30       39.12      -89.23    3.60    130   0
# 2            -84.58        0.00        0.00    0.10     10   0
# 3            -94.37        0.00        0.00    0.60     17   0
# 4            -90.68       37.63      -90.65    2.30    300   0
# ...             ...         ...         ...     ...    ...  ..
# 60109        -90.54       30.08      -90.53    0.60    150   0
# 60110        -90.92       34.78      -90.90    5.75     40   0
# 60111        -89.53       31.61      -89.49    5.59    100   0
# 60112        -87.24       30.77      -87.23    0.78     75   0
# 60113        -80.53       34.89      -80.52    0.90     75   0
#
#        Adj_Property_Loss
# 0              29.532376
# 1               2.953238
# 2               0.295324
# 3               0.029532
# 4               2.953238
# ...                  ...
# 60109           0.000000
# 60110           0.054598
# 60111           0.109195
# 60112           0.010920
# 60113           0.054598
#
# [60114 rows x 23 columns]

# %%
# create database
from config import password
connection_string = f"postgres:{password}@localhost:5432/tornado"
# connection_string = f"postgres:postgres@localhost:5432/Tornado"
engine = create_engine(f'postgresql://{connection_string}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-c2e4cc18756b> in <module>
#       1 # create database
# ----> 2 from config import password
#       3 connection_string = f"postgres:{password}@localhost:5432/tornado"
#       4 # connection_string = f"postgres:postgres@localhost:5432/Tornado"
#       5 engine = create_engine(f'postgresql://{connection_string}')
#
# ModuleNotFoundError: No module named 'config'

# %%
# Put data into database
tornado_data.to_sql(name='tornado_data', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from tornado_data', con=engine).head()

# %%
# Get X_train, X_test, y_train, y_test
# Scale data
# Run prediction model - neural network

# %%
# Split our preprocessed data into our features and target arrays
y = tornado_data['Adj_Property_Loss']
tornado_data = tornado_data.drop(columns=['Adj_Property_Loss','Property_Loss', 'Date', 'Time','om','Year','Day','Time_Zone','State','State_No'])
tornado_data.head()
# Out:
#    Month  State_FIPS  Magnitude  Injuries  Fatalities  Crop_Loss  \
# 0      1          29          3         3           0        0.0
# 1      1          17          3         3           0        0.0
# 2      1          39          1         1           0        0.0
# 3      1           5          3         1           1        0.0
# 4      1          29          2         5           0        0.0
#
#    Starting_Lat  Starting_Lon  Ending_Lat  Ending_Lon  Length  Width  fc
# 0         38.77        -90.22       38.83      -90.03     9.5    150   0
# 1         39.10        -89.30       39.12      -89.23     3.6    130   0
# 2         40.88        -84.58        0.00        0.00     0.1     10   0
# 3         34.40        -94.37        0.00        0.00     0.6     17   0
# 4         37.60        -90.68       37.63      -90.65     2.3    300   0

# %%
# Convert categorical data to numeric with `pd.get_dummies`
tornado_data = pd.get_dummies(tornado_data, drop_first=True)
len(tornado_data.columns)
# Out:
# 13

# %%
X_train, X_test, y_train, y_test = train_test_split(tornado_data, y, test_size=0.2)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=200, activation="relu", input_dim=13))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=100, activation="relu"))

# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               2800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 23,001
# Trainable params: 23,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="mse", optimizer="rmsprop", metrics=["mae"])

# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2943.5164 - mae: 3.3495
# Epoch 2/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2866.7444 - mae: 3.4340
# Epoch 3/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2849.1445 - mae: 3.4304
# Epoch 4/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2874.9360 - mae: 3.5037
# Epoch 5/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2839.1716 - mae: 3.5688
# Epoch 6/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2848.0891 - mae: 3.4779
# Epoch 7/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2848.0776 - mae: 3.4726
# Epoch 8/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2831.4441 - mae: 3.3935
# Epoch 9/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2822.8037 - mae: 3.4550
# Epoch 10/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2847.7361 - mae: 3.4124
# Epoch 11/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2846.4475 - mae: 3.3936
# Epoch 12/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2813.9658 - mae: 3.3320
# Epoch 13/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2833.9456 - mae: 3.3150
# Epoch 14/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2838.7864 - mae: 3.4178
# Epoch 15/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2890.6489 - mae: 3.4067
# Epoch 16/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2882.9561 - mae: 3.3794
# Epoch 17/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2891.4180 - mae: 3.3254
# Epoch 18/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2903.1833 - mae: 3.4418
# Epoch 19/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2877.4365 - mae: 3.3619
# Epoch 20/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2924.4229 - mae: 3.4120
# Epoch 21/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2883.0862 - mae: 3.3145
# Epoch 22/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2900.7490 - mae: 3.3134
# Epoch 23/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2899.0034 - mae: 3.3643
# Epoch 24/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2855.3962 - mae: 3.2865
# Epoch 25/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2869.0979 - mae: 3.3761
# Epoch 26/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2873.4514 - mae: 3.3974
# Epoch 27/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2824.5945 - mae: 3.3720
# Epoch 28/150
# 1503/1503 [==============================] - ETA: 0s - loss: 2882.5701 - mae: 3.35 - 2s 1ms/step - loss: 2861.9832 - mae: 3.3417
# Epoch 29/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2858.9653 - mae: 3.4569
# Epoch 30/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2851.7991 - mae: 3.3761
# Epoch 31/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2849.7102 - mae: 3.3340
# Epoch 32/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2846.9744 - mae: 3.4157
# Epoch 33/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2869.1533 - mae: 3.4347
# Epoch 34/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2869.5813 - mae: 3.4390
# Epoch 35/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2845.6804 - mae: 3.4035
# Epoch 36/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2852.4253 - mae: 3.4121
# Epoch 37/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2868.5125 - mae: 3.4170
# Epoch 38/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2849.7478 - mae: 3.4491
# Epoch 39/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2819.2007 - mae: 3.3305
# Epoch 40/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2859.3206 - mae: 3.3925
# Epoch 41/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2839.6025 - mae: 3.3834
# Epoch 42/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2907.5051 - mae: 3.2691
# Epoch 43/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2883.3645 - mae: 3.2307
# Epoch 44/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2868.5085 - mae: 3.1948
# Epoch 45/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2881.1062 - mae: 3.1967
# Epoch 46/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2877.7593 - mae: 3.3078
# Epoch 47/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2822.7612 - mae: 3.2235
# Epoch 48/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2827.5923 - mae: 3.2057
# Epoch 49/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2844.7136 - mae: 3.2572
# Epoch 50/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2893.9834 - mae: 3.2456
# Epoch 51/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2898.7458 - mae: 3.2748
# Epoch 52/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2836.7466 - mae: 3.2305
# Epoch 53/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2858.0220 - mae: 3.3399
# Epoch 54/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2852.9758 - mae: 3.3412
# Epoch 55/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2841.6428 - mae: 3.3467
# Epoch 56/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2850.8953 - mae: 3.3926
# Epoch 57/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2846.4023 - mae: 3.3000
# Epoch 58/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2833.9719 - mae: 3.3296
# Epoch 59/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2834.5964 - mae: 3.3244
# Epoch 60/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2816.1541 - mae: 3.3154
# Epoch 61/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2850.0032 - mae: 3.3684
# Epoch 62/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2862.8757 - mae: 3.3580
# Epoch 63/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2850.9543 - mae: 3.2895
# Epoch 64/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2882.1648 - mae: 3.2750
# Epoch 65/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2865.5671 - mae: 3.3328
# Epoch 66/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2860.1853 - mae: 3.2150
# Epoch 67/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2872.4075 - mae: 3.1214
# Epoch 68/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2867.0798 - mae: 3.0973
# Epoch 69/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2877.8611 - mae: 3.0511
# Epoch 70/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2882.4688 - mae: 3.0202
# Epoch 71/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2834.7305 - mae: 3.0742
# Epoch 72/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2871.3623 - mae: 3.1075
# Epoch 73/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2854.5649 - mae: 3.1535
# Epoch 74/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2831.5681 - mae: 3.1457
# Epoch 75/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2834.8110 - mae: 3.1272
# Epoch 76/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2867.7180 - mae: 3.1753
# Epoch 77/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2850.4766 - mae: 3.1695
# Epoch 78/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2870.5449 - mae: 3.1767
# Epoch 79/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2862.0535 - mae: 3.2319
# Epoch 80/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2866.4902 - mae: 3.2052
# Epoch 81/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2866.6421 - mae: 3.2026
# Epoch 82/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2903.8503 - mae: 3.3364
# Epoch 83/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2899.0696 - mae: 3.2694
# Epoch 84/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2903.4639 - mae: 3.3060
# Epoch 85/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2865.5942 - mae: 3.2773
# Epoch 86/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2853.7793 - mae: 3.2409
# Epoch 87/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2867.6714 - mae: 3.2815
# Epoch 88/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2877.2451 - mae: 3.2390
# Epoch 89/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2805.2847 - mae: 3.2289
# Epoch 90/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2861.7302 - mae: 3.2721
# Epoch 91/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2838.1816 - mae: 3.2662
# Epoch 92/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2826.4768 - mae: 3.2452
# Epoch 93/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2829.6604 - mae: 3.2646
# Epoch 94/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2814.2803 - mae: 3.2412
# Epoch 95/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2844.9705 - mae: 3.2832
# Epoch 96/150
# 1503/1503 [==============================] - ETA: 0s - loss: 2873.2209 - mae: 3.24 - 2s 1ms/step - loss: 2851.9045 - mae: 3.2332
# Epoch 97/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2816.1257 - mae: 3.2181
# Epoch 98/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2857.4089 - mae: 3.2830
# Epoch 99/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2830.1348 - mae: 3.2254
# Epoch 100/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2813.9761 - mae: 3.2045
# Epoch 101/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2753.9609 - mae: 3.2716
# Epoch 102/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2825.4827 - mae: 3.2105
# Epoch 103/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2840.2249 - mae: 3.2001
# Epoch 104/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2825.9465 - mae: 3.2013
# Epoch 105/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2820.5867 - mae: 3.1943
# Epoch 106/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2807.0566 - mae: 3.2256
# Epoch 107/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2764.2280 - mae: 3.2301
# Epoch 108/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2839.6724 - mae: 3.2301
# Epoch 109/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2810.6082 - mae: 3.2106
# Epoch 110/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2840.7542 - mae: 3.2093
# Epoch 111/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2838.5493 - mae: 3.2735
# Epoch 112/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2761.5535 - mae: 3.2709
# Epoch 113/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2834.8948 - mae: 3.2796
# Epoch 114/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2825.6860 - mae: 3.3048
# Epoch 115/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2858.7639 - mae: 3.3007
# Epoch 116/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2900.4282 - mae: 3.4218
# Epoch 117/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2819.0515 - mae: 3.4157
# Epoch 118/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2797.5137 - mae: 3.4787
# Epoch 119/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2799.2600 - mae: 3.4072
# Epoch 120/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2818.4641 - mae: 3.4145
# Epoch 121/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2791.4849 - mae: 3.3647
# Epoch 122/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2802.0059 - mae: 3.4257
# Epoch 123/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2843.8086 - mae: 3.4475
# Epoch 124/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2822.5808 - mae: 3.3966
# Epoch 125/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2825.8879 - mae: 3.3385
# Epoch 126/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2779.9451 - mae: 3.3766
# Epoch 127/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2781.7107 - mae: 3.2983
# Epoch 128/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2737.8655 - mae: 3.3831
# Epoch 129/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2810.6033 - mae: 3.3521
# Epoch 130/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2816.4868 - mae: 3.3312
# Epoch 131/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2784.7605 - mae: 3.3690
# Epoch 132/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2783.6812 - mae: 3.4069
# Epoch 133/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2757.9004 - mae: 3.3814
# Epoch 134/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2793.7100 - mae: 3.2335
# Epoch 135/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2742.1458 - mae: 3.2642
# Epoch 136/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2751.9780 - mae: 3.2396
# Epoch 137/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2771.3689 - mae: 3.1485
# Epoch 138/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2675.4827 - mae: 3.1219
# Epoch 139/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2727.5950 - mae: 3.1440
# Epoch 140/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2734.8882 - mae: 3.1269
# Epoch 141/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2744.4678 - mae: 3.1600
# Epoch 142/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2730.9487 - mae: 3.1344
# Epoch 143/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2729.9961 - mae: 3.1228
# Epoch 144/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2722.2830 - mae: 3.1780
# Epoch 145/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2723.1045 - mae: 3.1687
# Epoch 146/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2739.1223 - mae: 3.2171
# Epoch 147/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2765.9900 - mae: 3.1699
# Epoch 148/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2695.3206 - mae: 3.1547
# Epoch 149/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2664.6885 - mae: 3.2066
# Epoch 150/150
# 1503/1503 [==============================] - 2s 1ms/step - loss: 2758.3086 - mae: 3.1719

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="mae")
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 376/376 - 0s - loss: 905.0318 - mae: 2.4370
# Loss: 905.0317993164062, Accuracy: 2.43699049949646
