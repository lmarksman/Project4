# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import make_classification
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import cpi
cpi.update()
from datetime import date
from sqlalchemy import create_engine
import tensorflow as tf

# %%
# Read in data
tornado_data = pd.read_csv('Tornadoes_SPC_1950to2015.csv')
tornado_data.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'stf', 'stn', 'mag',
#        'inj', 'fat', 'loss', 'closs', 'slat', 'slon', 'elat', 'elon', 'len',
#        'wid', 'fc'],
#       dtype='object')

# %%
# Clean up file
tornado_data.rename(columns = {'yr':'Year', 'mo':'Month','dy':'Day','date':'Date','time':'Time','tz':'Time_Zone',
                               'st':'State','stf':'State_FIPS','stn':'State_No','mag':'Magnitude','inj':'Injuries',
                               'fat':'Fatalities','loss':'Property_Loss','closs':'Crop_Loss','slat':'Starting_Lat',
                               'slon':'Starting_Lon','elat':'Ending_Lat','elon':'Ending_Lon','len':'Length',
                               'wid':'Width'}, inplace = True)
tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 60109  607506  2015     12   28  12/28/2015   3:20:00          3    LA
# 60110  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 60111  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 60112  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 60113  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Fatalities  Property_Loss  Crop_Loss  \
# 0              29         1  ...           0           6.00        0.0
# 1              17         2  ...           0           5.00        0.0
# 2              39         1  ...           0           4.00        0.0
# 3               5         1  ...           1           3.00        0.0
# 4              29         2  ...           0           5.00        0.0
# ...           ...       ...  ...         ...            ...        ...
# 60109          22         0  ...           0           0.00        0.0
# 60110           5         0  ...           0           0.05        0.0
# 60111          28         0  ...           0           0.10        0.0
# 60112          12         0  ...           0           0.01        0.0
# 60113          37         0  ...           0           0.05        0.0
#
#        Starting_Lat  Starting_Lon  Ending_Lat  Ending_Lon  Length  Width  fc
# 0             38.77        -90.22       38.83      -90.03    9.50    150   0
# 1             39.10        -89.30       39.12      -89.23    3.60    130   0
# 2             40.88        -84.58        0.00        0.00    0.10     10   0
# 3             34.40        -94.37        0.00        0.00    0.60     17   0
# 4             37.60        -90.68       37.63      -90.65    2.30    300   0
# ...             ...           ...         ...         ...     ...    ...  ..
# 60109         30.08        -90.54       30.08      -90.53    0.60    150   0
# 60110         34.70        -90.92       34.78      -90.90    5.75     40   0
# 60111         31.54        -89.53       31.61      -89.49    5.59    100   0
# 60112         30.76        -87.24       30.77      -87.23    0.78     75   0
# 60113         34.88        -80.53       34.89      -80.52    0.90     75   0
#
# [60114 rows x 22 columns]

# %%
# Remove zeroes from Property Loss column
tornado_data = tornado_data[tornado_data['Property_Loss'] > 0]
tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 60106  607040  2015     12   27  12/27/2015  20:16:00          3    LA
# 60110  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 60111  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 60112  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 60113  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Fatalities  Property_Loss  Crop_Loss  \
# 0              29         1  ...           0           6.00        0.0
# 1              17         2  ...           0           5.00        0.0
# 2              39         1  ...           0           4.00        0.0
# 3               5         1  ...           1           3.00        0.0
# 4              29         2  ...           0           5.00        0.0
# ...           ...       ...  ...         ...            ...        ...
# 60106          22         0  ...           0           0.25        0.0
# 60110           5         0  ...           0           0.05        0.0
# 60111          28         0  ...           0           0.10        0.0
# 60112          12         0  ...           0           0.01        0.0
# 60113          37         0  ...           0           0.05        0.0
#
#        Starting_Lat  Starting_Lon  Ending_Lat  Ending_Lon  Length  Width  fc
# 0             38.77        -90.22       38.83      -90.03    9.50    150   0
# 1             39.10        -89.30       39.12      -89.23    3.60    130   0
# 2             40.88        -84.58        0.00        0.00    0.10     10   0
# 3             34.40        -94.37        0.00        0.00    0.60     17   0
# 4             37.60        -90.68       37.63      -90.65    2.30    300   0
# ...             ...           ...         ...         ...     ...    ...  ..
# 60106         32.61        -93.88       32.64      -93.88    2.27    144   0
# 60110         34.70        -90.92       34.78      -90.90    5.75     40   0
# 60111         31.54        -89.53       31.61      -89.49    5.59    100   0
# 60112         30.76        -87.24       30.77      -87.23    0.78     75   0
# 60113         34.88        -80.53       34.89      -80.52    0.90     75   0
#
# [36319 rows x 22 columns]

# %%
# Export data to csv to process through python and add Census API data
tornado_data.to_csv('tornado_data_no_zeroes.csv')

# %%
# Read in csv with Census data added
tornado_data = pd.read_csv('tornado_data_census.csv')
tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 36314  607040  2015     12   27  12/27/2015  20:16:00          3    LA
# 36315  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 36316  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 36317  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 36318  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Crop_Loss  Starting_Lat  Starting_Lon  \
# 0              29         1  ...        0.0         38.77        -90.22
# 1              17         2  ...        0.0         39.10        -89.30
# 2              39         1  ...        0.0         40.88        -84.58
# 3               5         1  ...        0.0         34.40        -94.37
# 4              29         2  ...        0.0         37.60        -90.68
# ...           ...       ...  ...        ...           ...           ...
# 36314          22         0  ...        0.0         32.61        -93.88
# 36315           5         0  ...        0.0         34.70        -90.92
# 36316          28         0  ...        0.0         31.54        -89.53
# 36317          12         0  ...        0.0         30.76        -87.24
# 36318          37         0  ...        0.0         34.88        -80.53
#
#        Ending_Lat  Ending_Lon  Length  Width  fc   Income  Pop_Density
# 0           38.83      -90.03    9.50    150   0  35368.0      3115.77
# 1           39.12      -89.23    3.60    130   0  49840.0        24.06
# 2            0.00        0.00    0.10     10   0  36734.0       767.15
# 3            0.00        0.00    0.60     17   0  37621.0        10.65
# 4           37.63      -90.65    2.30    300   0  37614.0        27.70
# ...           ...         ...     ...    ...  ..      ...          ...
# 36314       32.64      -93.88    2.27    144   0  65188.0       515.20
# 36315       34.78      -90.90    5.75     40   0  33167.0         8.00
# 36316       31.61      -89.49    5.59    100   0  34676.0        40.85
# 36317       30.77      -87.23    0.78     75   0  78587.0       175.61
# 36318       34.89      -80.52    0.90     75   0  50863.0        68.49
#
# [36319 rows x 24 columns]

# %%
# Remove any NANs from Census columns
tornado_data = tornado_data.replace(r'^s*$', float('NaN'), regex = True)
tornado_data.dropna(inplace = True)
tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 36314  607040  2015     12   27  12/27/2015  20:16:00          3    LA
# 36315  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 36316  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 36317  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 36318  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Crop_Loss  Starting_Lat  Starting_Lon  \
# 0              29         1  ...        0.0         38.77        -90.22
# 1              17         2  ...        0.0         39.10        -89.30
# 2              39         1  ...        0.0         40.88        -84.58
# 3               5         1  ...        0.0         34.40        -94.37
# 4              29         2  ...        0.0         37.60        -90.68
# ...           ...       ...  ...        ...           ...           ...
# 36314          22         0  ...        0.0         32.61        -93.88
# 36315           5         0  ...        0.0         34.70        -90.92
# 36316          28         0  ...        0.0         31.54        -89.53
# 36317          12         0  ...        0.0         30.76        -87.24
# 36318          37         0  ...        0.0         34.88        -80.53
#
#        Ending_Lat  Ending_Lon  Length  Width  fc   Income  Pop_Density
# 0           38.83      -90.03    9.50    150   0  35368.0      3115.77
# 1           39.12      -89.23    3.60    130   0  49840.0        24.06
# 2            0.00        0.00    0.10     10   0  36734.0       767.15
# 3            0.00        0.00    0.60     17   0  37621.0        10.65
# 4           37.63      -90.65    2.30    300   0  37614.0        27.70
# ...           ...         ...     ...    ...  ..      ...          ...
# 36314       32.64      -93.88    2.27    144   0  65188.0       515.20
# 36315       34.78      -90.90    5.75     40   0  33167.0         8.00
# 36316       31.61      -89.49    5.59    100   0  34676.0        40.85
# 36317       30.77      -87.23    0.78     75   0  78587.0       175.61
# 36318       34.89      -80.52    0.90     75   0  50863.0        68.49
#
# [36182 rows x 24 columns]

# %%
# Translate Property Loss to $ amounts - use midpoint in each range, translate to fraction of million
# 1 = .000025
# 2 = .000275
# 3 = .00275
# 4 = .0275
# 5 = .275
# 6 = 2.75
# 7 = 27.5
# 8 = 275
# 9 = 2750

tornado_data['Property_Loss'] = tornado_data['Property_Loss'].replace([1, 2, 3, 4, 5, 6, 7, 8, 9], 
                                    [.000025, .000275, .00275, .0275, .275, 2.75, 27.5, 275, 2750])
tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 36314  607040  2015     12   27  12/27/2015  20:16:00          3    LA
# 36315  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 36316  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 36317  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 36318  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Crop_Loss  Starting_Lat  Starting_Lon  \
# 0              29         1  ...        0.0         38.77        -90.22
# 1              17         2  ...        0.0         39.10        -89.30
# 2              39         1  ...        0.0         40.88        -84.58
# 3               5         1  ...        0.0         34.40        -94.37
# 4              29         2  ...        0.0         37.60        -90.68
# ...           ...       ...  ...        ...           ...           ...
# 36314          22         0  ...        0.0         32.61        -93.88
# 36315           5         0  ...        0.0         34.70        -90.92
# 36316          28         0  ...        0.0         31.54        -89.53
# 36317          12         0  ...        0.0         30.76        -87.24
# 36318          37         0  ...        0.0         34.88        -80.53
#
#        Ending_Lat  Ending_Lon  Length  Width  fc   Income  Pop_Density
# 0           38.83      -90.03    9.50    150   0  35368.0      3115.77
# 1           39.12      -89.23    3.60    130   0  49840.0        24.06
# 2            0.00        0.00    0.10     10   0  36734.0       767.15
# 3            0.00        0.00    0.60     17   0  37621.0        10.65
# 4           37.63      -90.65    2.30    300   0  37614.0        27.70
# ...           ...         ...     ...    ...  ..      ...          ...
# 36314       32.64      -93.88    2.27    144   0  65188.0       515.20
# 36315       34.78      -90.90    5.75     40   0  33167.0         8.00
# 36316       31.61      -89.49    5.59    100   0  34676.0        40.85
# 36317       30.77      -87.23    0.78     75   0  78587.0       175.61
# 36318       34.89      -80.52    0.90     75   0  50863.0        68.49
#
# [36182 rows x 24 columns]

# %%
# Adjust $ amount for inflation
tornado_data["Adj_Property_Loss"] = tornado_data.apply(lambda x: cpi.inflate(x["Property_Loss"], x["Year"]), axis=1)

tornado_data
# Out:
#            om  Year  Month  Day        Date      Time  Time_Zone State  \
# 0           1  1950      1    3    1/3/1950  11:00:00          3    MO
# 1           2  1950      1    3    1/3/1950  11:55:00          3    IL
# 2           3  1950      1    3    1/3/1950  16:00:00          3    OH
# 3           4  1950      1   13   1/13/1950   5:25:00          3    AR
# 4           5  1950      1   25   1/25/1950  19:30:00          3    MO
# ...       ...   ...    ...  ...         ...       ...        ...   ...
# 36314  607040  2015     12   27  12/27/2015  20:16:00          3    LA
# 36315  613277  2015     12   28  12/28/2015   4:46:00          3    AR
# 36316  607307  2015     12   28  12/28/2015   5:43:00          3    MS
# 36317  612738  2015     12   28  12/28/2015   8:30:00          3    FL
# 36318  612739  2015     12   28  12/28/2015  15:58:00          3    NC
#
#        State_FIPS  State_No  ...  Starting_Lat  Starting_Lon  Ending_Lat  \
# 0              29         1  ...         38.77        -90.22       38.83
# 1              17         2  ...         39.10        -89.30       39.12
# 2              39         1  ...         40.88        -84.58        0.00
# 3               5         1  ...         34.40        -94.37        0.00
# 4              29         2  ...         37.60        -90.68       37.63
# ...           ...       ...  ...           ...           ...         ...
# 36314          22         0  ...         32.61        -93.88       32.64
# 36315           5         0  ...         34.70        -90.92       34.78
# 36316          28         0  ...         31.54        -89.53       31.61
# 36317          12         0  ...         30.76        -87.24       30.77
# 36318          37         0  ...         34.88        -80.53       34.89
#
#        Ending_Lon  Length  Width  fc   Income  Pop_Density  Adj_Property_Loss
# 0          -90.03    9.50    150   0  35368.0      3115.77          29.532376
# 1          -89.23    3.60    130   0  49840.0        24.06           2.953238
# 2            0.00    0.10     10   0  36734.0       767.15           0.295324
# 3            0.00    0.60     17   0  37621.0        10.65           0.029532
# 4          -90.65    2.30    300   0  37614.0        27.70           2.953238
# ...           ...     ...    ...  ..      ...          ...                ...
# 36314      -93.88    2.27    144   0  65188.0       515.20           0.272988
# 36315      -90.90    5.75     40   0  33167.0         8.00           0.054598
# 36316      -89.49    5.59    100   0  34676.0        40.85           0.109195
# 36317      -87.23    0.78     75   0  78587.0       175.61           0.010920
# 36318      -80.52    0.90     75   0  50863.0        68.49           0.054598
#
# [36182 rows x 25 columns]

# %%
# create database
from config import password
connection_string = f"postgres:{password}@localhost:5432/tornado"
# connection_string = f"postgres:postgres@localhost:5432/Tornado"
engine = create_engine(f'postgresql://{connection_string}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-c2e4cc18756b> in <module>
#       1 # create database
# ----> 2 from config import password
#       3 connection_string = f"postgres:{password}@localhost:5432/tornado"
#       4 # connection_string = f"postgres:postgres@localhost:5432/Tornado"
#       5 engine = create_engine(f'postgresql://{connection_string}')
#
# ModuleNotFoundError: No module named 'config'

# %%
# Put data into database
tornado_data.to_sql(name='tornado_data', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from tornado_data', con=engine).head()

# %%
# Split our preprocessed data into our features and target arrays
y = tornado_data['Adj_Property_Loss']
tornado_data = tornado_data.drop(columns=['Adj_Property_Loss','Property_Loss', 'Date', 'Time','om','Year','Day',
                                          'Time_Zone','State','State_No','fc'])
tornado_data
# Out:
#        Month  State_FIPS  Magnitude  Injuries  Fatalities  Crop_Loss  \
# 0          1          29          3         3           0        0.0
# 1          1          17          3         3           0        0.0
# 2          1          39          1         1           0        0.0
# 3          1           5          3         1           1        0.0
# 4          1          29          2         5           0        0.0
# ...      ...         ...        ...       ...         ...        ...
# 36314     12          22          1         0           0        0.0
# 36315     12           5          2         0           0        0.0
# 36316     12          28          1         0           0        0.0
# 36317     12          12          1         0           0        0.0
# 36318     12          37          0         0           0        0.0
#
#        Starting_Lat  Starting_Lon  Ending_Lat  Ending_Lon  Length  Width  \
# 0             38.77        -90.22       38.83      -90.03    9.50    150
# 1             39.10        -89.30       39.12      -89.23    3.60    130
# 2             40.88        -84.58        0.00        0.00    0.10     10
# 3             34.40        -94.37        0.00        0.00    0.60     17
# 4             37.60        -90.68       37.63      -90.65    2.30    300
# ...             ...           ...         ...         ...     ...    ...
# 36314         32.61        -93.88       32.64      -93.88    2.27    144
# 36315         34.70        -90.92       34.78      -90.90    5.75     40
# 36316         31.54        -89.53       31.61      -89.49    5.59    100
# 36317         30.76        -87.24       30.77      -87.23    0.78     75
# 36318         34.88        -80.53       34.89      -80.52    0.90     75
#
#         Income  Pop_Density
# 0      35368.0      3115.77
# 1      49840.0        24.06
# 2      36734.0       767.15
# 3      37621.0        10.65
# 4      37614.0        27.70
# ...        ...          ...
# 36314  65188.0       515.20
# 36315  33167.0         8.00
# 36316  34676.0        40.85
# 36317  78587.0       175.61
# 36318  50863.0        68.49
#
# [36182 rows x 14 columns]

# %%
# Convert categorical data to numeric with `pd.get_dummies`
tornado_data = pd.get_dummies(tornado_data, drop_first=True)
len(tornado_data.columns)
# Out:
# 14

# %%
X_train, X_test, y_train, y_test = train_test_split(tornado_data, y, test_size=0.2)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=200, activation="relu", input_dim=14))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=100, activation="relu"))

# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 200)               3000
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 23,201
# Trainable params: 23,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="mse", optimizer="rmsprop", metrics=["mae"])

# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=120)
# Out:
# Epoch 1/120
# 905/905 [==============================] - 2s 1ms/step - loss: 4509.9268 - mae: 5.5580
# Epoch 2/120
# 905/905 [==============================] - 2s 2ms/step - loss: 4371.0801 - mae: 5.3946
# Epoch 3/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4287.1519 - mae: 5.6039
# Epoch 4/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4288.4429 - mae: 5.6106
# Epoch 5/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4292.3452 - mae: 5.4988
# Epoch 6/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4259.5640 - mae: 5.5529
# Epoch 7/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4286.4790 - mae: 5.6137
# Epoch 8/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4297.3643 - mae: 5.5378
# Epoch 9/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4282.7583 - mae: 5.3307
# Epoch 10/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4306.6680 - mae: 5.2331
# Epoch 11/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4249.4287 - mae: 5.0236
# Epoch 12/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4205.6431 - mae: 5.1319
# Epoch 13/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4263.6758 - mae: 5.0219
# Epoch 14/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4255.4419 - mae: 5.0179
# Epoch 15/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4179.8623 - mae: 5.0555
# Epoch 16/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4308.2349 - mae: 5.0862
# Epoch 17/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4254.4785 - mae: 5.0936
# Epoch 18/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4245.1362 - mae: 5.0151
# Epoch 19/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4296.2168 - mae: 5.0396
# Epoch 20/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4233.3013 - mae: 4.8627
# Epoch 21/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4277.3687 - mae: 5.0095
# Epoch 22/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4248.9961 - mae: 5.0263
# Epoch 23/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4296.4614 - mae: 5.0865
# Epoch 24/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4251.8706 - mae: 5.0282
# Epoch 25/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4238.3462 - mae: 5.0026
# Epoch 26/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4285.3169 - mae: 5.0936
# Epoch 27/120
# 905/905 [==============================] - 2s 2ms/step - loss: 4274.3306 - mae: 4.9147
# Epoch 28/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4249.1621 - mae: 5.0896
# Epoch 29/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4249.8691 - mae: 5.1061
# Epoch 30/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4272.2646 - mae: 5.0905
# Epoch 31/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4167.4614 - mae: 4.9206
# Epoch 32/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4275.5771 - mae: 5.1733
# Epoch 33/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4250.4087 - mae: 5.2253
# Epoch 34/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4205.4370 - mae: 4.9875
# Epoch 35/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4276.9121 - mae: 5.3609
# Epoch 36/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4259.3481 - mae: 4.9929
# Epoch 37/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4229.4849 - mae: 4.9533
# Epoch 38/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4244.3794 - mae: 5.0204
# Epoch 39/120
# 905/905 [==============================] - 2s 2ms/step - loss: 4281.3745 - mae: 5.0863
# Epoch 40/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4228.6050 - mae: 5.0625
# Epoch 41/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4292.3848 - mae: 5.1107
# Epoch 42/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4202.5728 - mae: 5.1102
# Epoch 43/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4310.7900 - mae: 5.1282
# Epoch 44/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4312.7300 - mae: 5.2226
# Epoch 45/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4217.1226 - mae: 5.1180
# Epoch 46/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4246.7915 - mae: 5.0457
# Epoch 47/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4257.3589 - mae: 5.1202
# Epoch 48/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4256.7959 - mae: 4.9620
# Epoch 49/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4274.0713 - mae: 5.0473
# Epoch 50/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4246.7910 - mae: 4.9527
# Epoch 51/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4220.6968 - mae: 4.9389
# Epoch 52/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4246.6338 - mae: 4.8610
# Epoch 53/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4229.8394 - mae: 4.9489
# Epoch 54/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4268.0894 - mae: 5.0464
# Epoch 55/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4224.9229 - mae: 5.0200
# Epoch 56/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4226.0298 - mae: 5.0530
# Epoch 57/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4266.3447 - mae: 5.1284
# Epoch 58/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4225.0649 - mae: 4.9671
# Epoch 59/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4226.0723 - mae: 5.0367
# Epoch 60/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4206.2578 - mae: 5.0414
# Epoch 61/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4161.0854 - mae: 4.9780
# Epoch 62/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4207.4263 - mae: 4.9988
# Epoch 63/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4196.1216 - mae: 5.0736
# Epoch 64/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4257.4629 - mae: 5.1962
# Epoch 65/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4262.7168 - mae: 5.1601
# Epoch 66/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4221.6006 - mae: 5.0610
# Epoch 67/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4209.9580 - mae: 5.2390
# Epoch 68/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4209.6543 - mae: 5.1418
# Epoch 69/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4269.4805 - mae: 5.2627
# Epoch 70/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4235.7998 - mae: 5.2060
# Epoch 71/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4234.2070 - mae: 5.1759
# Epoch 72/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4214.9302 - mae: 5.1917
# Epoch 73/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4205.8403 - mae: 5.1861
# Epoch 74/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4224.1621 - mae: 5.0613
# Epoch 75/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4170.9106 - mae: 5.1228
# Epoch 76/120
# 905/905 [==============================] - 1s 2ms/step - loss: 4204.0981 - mae: 5.1987
# Epoch 77/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4243.4106 - mae: 5.1791
# Epoch 78/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4233.5645 - mae: 5.1795
# Epoch 79/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4221.6465 - mae: 5.0371
# Epoch 80/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4228.6699 - mae: 5.1956
# Epoch 81/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4243.1523 - mae: 5.1789
# Epoch 82/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4239.3755 - mae: 5.1265
# Epoch 83/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4197.3467 - mae: 5.1002
# Epoch 84/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4216.4795 - mae: 5.1707
# Epoch 85/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4241.5303 - mae: 5.0964
# Epoch 86/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4204.3765 - mae: 5.1383
# Epoch 87/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4210.7773 - mae: 5.1177
# Epoch 88/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4256.1602 - mae: 5.1192
# Epoch 89/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4231.4731 - mae: 5.0642
# Epoch 90/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4225.4512 - mae: 5.1003
# Epoch 91/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4216.9512 - mae: 4.9674
# Epoch 92/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4236.4556 - mae: 5.0941
# Epoch 93/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4277.8862 - mae: 5.1325
# Epoch 94/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4225.0552 - mae: 4.9563
# Epoch 95/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4254.9814 - mae: 5.0278
# Epoch 96/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4248.7412 - mae: 5.0022
# Epoch 97/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4230.7788 - mae: 5.0955
# Epoch 98/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4178.9043 - mae: 5.0353
# Epoch 99/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4268.1460 - mae: 5.2227
# Epoch 100/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4231.7520 - mae: 5.1594
# Epoch 101/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4246.0645 - mae: 5.1499
# Epoch 102/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4207.9639 - mae: 5.0461
# Epoch 103/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4259.0781 - mae: 5.0785
# Epoch 104/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4271.7251 - mae: 5.0338
# Epoch 105/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4239.3652 - mae: 5.1898
# Epoch 106/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4230.0327 - mae: 5.0452
# Epoch 107/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4190.1050 - mae: 5.1816
# Epoch 108/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4200.9453 - mae: 5.1169
# Epoch 109/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4194.6812 - mae: 5.2079
# Epoch 110/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4190.7490 - mae: 5.2028
# Epoch 111/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4193.2954 - mae: 5.1845
# Epoch 112/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4202.3994 - mae: 5.1609
# Epoch 113/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4230.7871 - mae: 5.1323
# Epoch 114/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4159.6094 - mae: 5.1508
# Epoch 115/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4185.9111 - mae: 5.2230
# Epoch 116/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4160.6167 - mae: 5.2308
# Epoch 117/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4139.1445 - mae: 5.3771
# Epoch 118/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4196.4819 - mae: 5.3058
# Epoch 119/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4193.4854 - mae: 5.3306
# Epoch 120/120
# 905/905 [==============================] - 1s 1ms/step - loss: 4150.0249 - mae: 5.2042

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="mae")
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 227/227 - 0s - loss: 3407.4233 - mae: 4.9040 - 313ms/epoch - 1ms/step
# Loss: 3407.42333984375, Accuracy: 4.903984546661377
